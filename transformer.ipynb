# %%
# !pip install -U spacy
# !python -m spacy download en_core_web_sm
# Out:
# Collecting spacy
#   Using cached spacy-3.7.2-cp39-cp39-win_amd64.whl (12.2 MB)
# Collecting catalogue<2.1.0,>=2.0.6
#   Using cached catalogue-2.0.10-py3-none-any.whl (17 kB)
# Collecting srsly<3.0.0,>=2.4.3
#   Using cached srsly-2.4.8-cp39-cp39-win_amd64.whl (483 kB)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\jonat\anaconda3\lib\site-packages (from spacy) (4.62.3)
# Requirement already satisfied: jinja2 in c:\users\jonat\anaconda3\lib\site-packages (from spacy) (2.11.3)
# Collecting langcodes<4.0.0,>=3.2.0
#   Using cached langcodes-3.3.0-py3-none-any.whl (181 kB)
# Collecting typer<0.10.0,>=0.3.0
#   Using cached typer-0.9.0-py3-none-any.whl (45 kB)
# Collecting spacy-loggers<2.0.0,>=1.0.0
#   Using cached spacy_loggers-1.0.5-py3-none-any.whl (22 kB)
# Collecting preshed<3.1.0,>=3.0.2
#   Using cached preshed-3.0.9-cp39-cp39-win_amd64.whl (122 kB)
# Collecting pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4
#   Using cached pydantic-2.5.3-py3-none-any.whl (381 kB)
# Collecting spacy-legacy<3.1.0,>=3.0.11
#   Using cached spacy_legacy-3.0.12-py2.py3-none-any.whl (29 kB)
# Collecting smart-open<7.0.0,>=5.2.1
#   Using cached smart_open-6.4.0-py3-none-any.whl (57 kB)
# Collecting weasel<0.4.0,>=0.1.0
#   Using cached weasel-0.3.4-py3-none-any.whl (50 kB)
# Requirement already satisfied: packaging>=20.0 in c:\users\jonat\anaconda3\lib\site-packages (from spacy) (21.0)
# Collecting thinc<8.3.0,>=8.1.8
#   Using cached thinc-8.2.2-cp39-cp39-win_amd64.whl (1.5 MB)
# Collecting wasabi<1.2.0,>=0.9.1
#   Using cached wasabi-1.1.2-py3-none-any.whl (27 kB)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\jonat\anaconda3\lib\site-packages (from spacy) (2.26.0)
# Requirement already satisfied: numpy>=1.19.0 in c:\users\jonat\anaconda3\lib\site-packages (from spacy) (1.20.3)
# Requirement already satisfied: setuptools in c:\users\jonat\anaconda3\lib\site-packages (from spacy) (58.0.4)
# Collecting murmurhash<1.1.0,>=0.28.0
#   Using cached murmurhash-1.0.10-cp39-cp39-win_amd64.whl (25 kB)
# Collecting cymem<2.1.0,>=2.0.2
#   Using cached cymem-2.0.8-cp39-cp39-win_amd64.whl (39 kB)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\jonat\anaconda3\lib\site-packages (from packaging>=20.0->spacy) (3.0.4)
# Collecting typing-extensions>=4.6.1
#   Using cached typing_extensions-4.9.0-py3-none-any.whl (32 kB)
# Collecting pydantic-core==2.14.6
#   Using cached pydantic_core-2.14.6-cp39-none-win_amd64.whl (1.9 MB)
# Collecting annotated-types>=0.4.0
#   Using cached annotated_types-0.6.0-py3-none-any.whl (12 kB)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\jonat\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.2)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\jonat\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\jonat\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\jonat\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (1.26.7)
# Collecting blis<0.8.0,>=0.7.8
#   Downloading blis-0.7.11-cp39-cp39-win_amd64.whl (6.6 MB)
# Collecting confection<1.0.0,>=0.0.1
#   Downloading confection-0.1.4-py3-none-any.whl (35 kB)
# Requirement already satisfied: colorama in c:\users\jonat\anaconda3\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy) (0.4.4)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\users\jonat\anaconda3\lib\site-packages (from typer<0.10.0,>=0.3.0->spacy) (8.0.3)
# Collecting colorama
#   Using cached colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Collecting cloudpathlib<0.17.0,>=0.7.0
#   Downloading cloudpathlib-0.16.0-py3-none-any.whl (45 kB)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\jonat\anaconda3\lib\site-packages (from jinja2->spacy) (1.1.1)
# Installing collected packages: typing-extensions, pydantic-core, colorama, catalogue, annotated-types, srsly, pydantic, murmurhash, cymem, wasabi, typer, smart-open, preshed, confection, cloudpathlib, blis, weasel, thinc, spacy-loggers, spacy-legacy, langcodes, spacy
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing-extensions 3.10.0.2
#     Uninstalling typing-extensions-3.10.0.2:
#       Successfully uninstalled typing-extensions-3.10.0.2
#   Attempting uninstall: colorama
#     Found existing installation: colorama 0.4.4
#     Uninstalling colorama-0.4.4:
#       Successfully uninstalled colorama-0.4.4
# Successfully installed annotated-types-0.6.0 blis-0.7.11 catalogue-2.0.10 cloudpathlib-0.16.0 colorama-0.4.6 confection-0.1.4 cymem-2.0.8 langcodes-3.3.0 murmurhash-1.0.10 preshed-3.0.9 pydantic-2.5.3 pydantic-core-2.14.6 smart-open-6.4.0 spacy-3.7.2 spacy-legacy-3.0.12 spacy-loggers-1.0.5 srsly-2.4.8 thinc-8.2.2 typer-0.9.0 typing-extensions-4.9.0 wasabi-1.1.2 weasel-0.3.4
# Collecting en-core-web-sm==3.7.1
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.7.1/en_core_web_sm-3.7.1-py3-none-any.whl (12.8 MB)
# Requirement already satisfied: spacy<3.8.0,>=3.7.2 in c:\users\jonat\anaconda3\lib\site-packages (from en-core-web-sm==3.7.1) (3.7.2)
# Requirement already satisfied: numpy>=1.19.0 in c:\users\jonat\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.20.3)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\jonat\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.0.8)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\jonat\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.4.8)
# Requirement already satisfied: setuptools in c:\users\jonat\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (58.0.4)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\users\jonat\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.0.12)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\jonat\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (4.62.3)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in c:\users\jonat\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.9.0)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\jonat\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.0.10)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\jonat\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.0.9)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in c:\users\jonat\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (6.4.0)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\jonat\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.0.10)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\users\jonat\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.1.2)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\jonat\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.0.5)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in c:\users\jonat\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.5.3)
# Requirement already satisfied: packaging>=20.0 in c:\users\jonat\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (21.0)
# Requirement already satisfied: jinja2 in c:\users\jonat\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.11.3)
# Requirement already satisfied: thinc<8.3.0,>=8.1.8 in c:\users\jonat\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (8.2.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\jonat\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.3.0)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\jonat\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.26.0)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in c:\users\jonat\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.3.4)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\jonat\anaconda3\lib\site-packages (from packaging>=20.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.0.4)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\jonat\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.6.0)
# Requirement already satisfied: typing-extensions>=4.6.1 in c:\users\jonat\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (4.9.0)
# Requirement already satisfied: pydantic-core==2.14.6 in c:\users\jonat\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.14.6)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\jonat\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\jonat\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\jonat\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.26.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\jonat\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.0.4)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in c:\users\jonat\anaconda3\lib\site-packages (from thinc<8.3.0,>=8.1.8->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\jonat\anaconda3\lib\site-packages (from thinc<8.3.0,>=8.1.8->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.1.4)
# Requirement already satisfied: colorama in c:\users\jonat\anaconda3\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.4.6)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\users\jonat\anaconda3\lib\site-packages (from typer<0.10.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (8.0.3)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in c:\users\jonat\anaconda3\lib\site-packages (from weasel<0.4.0,>=0.1.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.16.0)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\jonat\anaconda3\lib\site-packages (from jinja2->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.1.1)
# Installing collected packages: en-core-web-sm
# Successfully installed en-core-web-sm-3.7.1
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
import spacy

# Load English tokenizer, tagger, parser and NER
nlp = spacy.load("en_core_web_sm")

# Process whole documents
text = ("When Sebastian Thrun started working on self-driving cars at "
        "Google in 2007, few people outside of the company took him "
        "seriously. “I can tell you very senior CEOs of major American "
        "car companies would shake my hand and turn away because I wasn’t "
        "worth talking to,” said Thrun, in an interview with Recode earlier "
        "this week.")
doc = nlp(text)

# Analyze syntax
print("Noun phrases:", [chunk.text for chunk in doc.noun_chunks])
print("Verbs:", [token.lemma_ for token in doc if token.pos_ == "VERB"])

# Find named entities, phrases and concepts
for entity in doc.ents:
    print(entity.text, entity.label_)
# Out:
# Noun phrases: ['Sebastian Thrun', 'self-driving cars', 'Google', 'few people', 'the company', 'him', 'I', 'you', 'very senior CEOs', 'major American car companies', 'my hand', 'I', 'Thrun', 'an interview', 'Recode']
# Verbs: ['start', 'work', 'drive', 'take', 'tell', 'shake', 'turn', 'talk', 'say']
# Sebastian Thrun PERSON
# Google ORG
# 2007 DATE
# American NORP
# Thrun PERSON
# Recode ORG
# earlier this week DATE
